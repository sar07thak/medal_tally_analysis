# %%
import pandas as pd 
import numpy as np

# %%
data = {
    "Name": ["A", "B", "A", "C"],
    "Age": [20, 21, 20, 22]
}

df = pd.DataFrame( data )

print( df.duplicated( subset=['Name']))

df.drop_duplicates( subset=['Name'] , inplace=True )
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
print( df.duplicated( ))
# Out:
# 0    False
# 1    False
# 3    False
# dtype: bool
